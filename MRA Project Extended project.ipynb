# %% [markdown]
# <h2>MRA Project PGP DSBA </h2>

# %%
# importing the essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_excel('/content/sample_data/Cafe_Data_MRA.xlsx')

# %%
data
# Out:
#              Date Bill Number                        Item Desc      Time  \
# 0      2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11
# 1      2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11
# 2      2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35
# 3      2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55
# 4      2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18
# ...           ...          ...                             ...       ...
# 145825 2010-05-22     N0028716  ZINZI WHITE  (GLS)              21:43:55
# 145826 2010-04-27     N0028343  ZINZI WHITE  (GLS)              20:52:11
# 145827 2010-05-28     N0028835  ZINZI WHITE  (GLS)              01:03:37
# 145828 2010-04-30     N0028399  ZINZI WHITE  (GLS)              23:44:37
# 145829 2010-07-09     N0029472  ZINZI WHITE (BTL)               00:31:51
#
#         Quantity   Rate     Tax  Discount   Total  Category
# ...

# %%
data.head()
# Out:
#         Date Bill Number                        Item Desc      Time  Quantity  \
# 0 2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11         1
# 1 2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11         1
# 2 2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35         1
# 3 2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55         1
# 4 2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18         1
#
#     Rate    Tax  Discount   Total  Category
# 0   50.0  11.88       0.0   61.88  BEVERAGE
# 1  100.0  23.75       0.0  123.75  BEVERAGE
# 2   40.0   9.50       0.0   49.50  BEVERAGE
# 3   50.0  11.88       0.0   61.88  BEVERAGE
# 4   45.0  10.69       0.0   55.69  BEVERAGE

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145830 entries, 0 to 145829
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          145830 non-null  datetime64[ns]
#  1   Bill Number   145830 non-null  object
#  2   Item Desc     145830 non-null  object
#  3   Time          145830 non-null  object
#  4   Quantity      145830 non-null  int64
#  5   Rate          145830 non-null  float64
#  6   Tax           145830 non-null  float64
#  7   Discount      145830 non-null  float64
#  8   Total         145830 non-null  float64
#  9   Category      145830 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 11.1+ MB

# %%
data.describe()
# Out:
#             Quantity           Rate            Tax       Discount  \
# count  145830.000000  145830.000000  145830.000000  145830.000000
# mean        1.121299     161.782259      48.929061       0.095079
# std         0.477237     102.244631      40.272851       3.720735
# min         1.000000       0.010000       0.000000       0.000000
# 25%         1.000000      95.000000      22.560000       0.000000
# 50%         1.000000     125.000000      32.060000       0.000000
# 75%         1.000000     225.000000      72.000000       0.000000
# max        30.000000    2100.000000    2731.250000     825.000000
#
#                Total
# count  145830.000000
# mean      224.959852
# std       164.960776
# min         0.010000
# 25%       117.560000
# 50%       167.060000
# 75%       315.000000
# max     14231.250000

# %%
data['Bill Number '].nunique()
# Out:
# 69982

# %% [markdown]
# There are 69,982 orders / bills in the dataset

# %%
145830/69982
# Out:
# 2.083821554113915

# %% [markdown]
# On avg, there are 2 rows per Bill, which indicates 2 Items / Products on avg per bill

# %%
data.Total.sum()
# Out:
# 32805895.27

# %% [markdown]
# Total Revenue (Annual Sales Proceeds) - 3.28 Crore

# %%
data.Quantity.sum()
# Out:
# 163519

# %% [markdown]
# Total units sold - 1.63 lakh units

# %%
32805895.27/163519
# Out:
# 200.6243633461555

# %%
32805895.27/69982
# Out:
# 468.7761891629276

# %%
## visualising the numeric variables
data.plot(kind='box', figsize=(20,15))

# %%
for column in data.columns:
    if data[column].dtype == 'int64' or data[column].dtype == 'float64':
        plt.figure(figsize=(20,8))
        sns.boxplot(data[column], color='Salmon')
        plt.show()

# %%
for column in data.columns:
    if data[column].dtype == 'int64' or data[column].dtype == 'float64':
        plt.figure(figsize=(20,8))
        sns.histplot(data[column])
        plt.show()

# %%
## the observation with the highest quantity
data[data['Quantity']==30]
# Out:
#            Date Bill Number                        Item Desc      Time  \
# 4780 2010-09-04     G0496879  ADD ON S                        23:59:34
#
#       Quantity  Rate     Tax  Discount   Total Category
# 4780        30  15.0  106.88       0.0  556.88     MISC

# %%
## the row with the most expensive product
data[data.Rate == 2100]
# Out:
#             Date Bill Number                        Item Desc      Time  \
# 59854 2010-05-29     N0028856  GOSSIPS CHARD AUS (BTL)         00:36:36
#
#        Quantity    Rate     Tax  Discount    Total Category
# 59854         1  2100.0  656.25       0.0  2756.25    WINES

# %%
## list of the most expensive items
data[data.Rate > 500].sort_values(by='Rate',ascending=False)
# Out:
#              Date Bill Number                        Item Desc      Time  \
# 59854  2010-05-29     N0028856  GOSSIPS CHARD AUS (BTL)         00:36:36
# 82019  2010-04-03     N0027886  MATEUS ROSE PORTUGAL(BTL)       21:36:57
# 2870   2010-04-23     N0028250  2 OCEAN PINOTAGE (BTL)          23:42:45
# 81760  2010-04-11     N0028022  MAISON PIERRE SAUV MARSAN       23:23:32
# 73079  2010-06-07     N0028973  J.PCHENET SPARKLING ROSE (BTL)  23:21:16
# ...           ...          ...                             ...       ...
# 73767  2010-08-16     N0030036  HOEGAARDEN MUG (1 LITRE)        18:51:11
# 101411 2010-06-22     N0029168  HOEGAARDEN MUG (1 LITRE)        20:45:33
# 39921  2010-08-12     N0029983  HOEGAARDEN MUG (1 LITRE)        15:57:54
# 29631  2010-08-09     N0029950  HOEGAARDEN MUG (1 LITRE)        01:19:00
# 68676  2010-07-15     N0029568  STELLA ARTOIS MUG (1 LTR)       22:10:48
#
#         Quantity    Rate     Tax  Discount    Total Category
# ...

# %%
data[data.Rate > 500].sort_values(by='Rate',ascending=False).head(50)
# Out:
#              Date Bill Number                        Item Desc      Time  \
# 59854  2010-05-29     N0028856  GOSSIPS CHARD AUS (BTL)         00:36:36
# 82019  2010-04-03     N0027886  MATEUS ROSE PORTUGAL(BTL)       21:36:57
# 2870   2010-04-23     N0028250  2 OCEAN PINOTAGE (BTL)          23:42:45
# 81760  2010-04-11     N0028022  MAISON PIERRE SAUV MARSAN       23:23:32
# 73079  2010-06-07     N0028973  J.PCHENET SPARKLING ROSE (BTL)  23:21:16
# 73080  2010-05-27     N0028811  J.PCHENET SPARKLING ROSE (BTL)  00:07:25
# 72787  2010-04-05     N0027941  J.PCHENET SPARKLING ROSE (BTL)  01:00:15
# 82015  2010-05-30     N0028870  MAISON PIERRE SAUV MARSAN       21:05:52
# 81759  2010-05-05     N0028455  MAISON PIERRE SAUV MARSAN       00:06:46
# 111980 2010-09-24     G0500273  FLAVOR 1000 GMS                 23:14:40
# 131976 2011-03-30     N0034025  STELLA 1LTR 2+1                 22:14:26
# 131975 2011-03-30     N0034021  STELLA 1LTR 2+1                 22:02:06
# ...

# %%
## Analysing on Bill / Order level:

# %%
data.groupby(data['Bill Number ']).sum().describe()
# Out:
#            Quantity          Rate           Tax      Discount         Total
# count  69982.000000  69982.000000  69982.000000  69982.000000  69982.000000
# mean       2.336587    337.125359    101.959431      0.198128    468.776189
# std        1.799691    229.855848     75.707835     10.697178    348.423861
# min        1.000000      1.000000      0.000000      0.000000      1.260000
# 25%        1.000000    180.000000     52.260000      0.000000    272.250000
# 50%        2.000000    285.000000     80.760000      0.000000    391.460000
# 75%        3.000000    440.000000    130.690000      0.000000    594.000000
# max       64.000000   3350.000000   2731.250000   2311.500000  14231.250000

# %%
data.groupby(data['Bill Number '])['Total'].sum().plot(kind='kde')

# %%
data.groupby(data['Bill Number '])['Total'].sum().plot(kind='box' )

# %%
data.groupby(data['Bill Number '])['Quantity'].sum().plot(kind='kde')

# %%
data.groupby(data['Bill Number '])['Quantity'].sum().plot(kind='box' )

# %%
## Analysing Rate at item level & Total and Quantity at bill level

# %%
data.columns
# Out:
# Index(['Date', 'Bill Number ', 'Item Desc', 'Time', 'Quantity', 'Rate', 'Tax',
#        'Discount', 'Total', 'Category'],
#       dtype='object')

# %%
data['Item Desc'].nunique()
# Out:
# 580

# %% [markdown]
# There are 580 unique items in the dataset

# %%
## the Best Earners

# %%
data.groupby(data['Item Desc'])['Quantity','Total'].sum().sort_values(by='Total',ascending=False).head(50)
# Out:
# /Users/shubhadeepbhattacharya/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                       Quantity       Total
# Item Desc
# NIRVANA HOOKAH SINGLE                     8686  2953134.60
# SAMBUCA                                   4765  2291058.00
# MINT FLAVOUR SINGLE                       6019  1840501.00
# CALCUTTA MINT                             3339  1640860.40
# N R G  HOOKAH                             2314  1193015.40
# GREAT LAKES SHAKE                         5914   843122.11
# GREEN APPLE FLAVOUR SINGLE                2590   793683.00
# JR.CHL AVALANCHE                          3446   713565.60
# SILVER APPLE SINGLE                       1985   673525.20
# POUTINE WITH FRIES                        3741   580284.11
# ...

# %%
## Net Revenue from 10% of the products (top 58 items)

# %%
data.groupby(data['Item Desc'])['Total'].sum().sort_values(ascending=False).head(58).sum()
# Out:
# 25506701.179999765

# %%
25506701.179999765/32805895.27
# Out:
# 0.7775035849524543

# %% [markdown]
# The top 58 products (10% of catalogue) (revenue) contribute to 77.75% of the total revenue

# %%
50/580
# Out:
# 0.08620689655172414

# %% [markdown]
# The top 50 products (9% of catalogue) (revenue) contribute to 75% of the total revenue

# %% [markdown]
# the Best sellers!

# %%
data.groupby(data['Item Desc'])['Quantity','Total'].sum().sort_values(by='Quantity',ascending=False).head(50)
# Out:
# /Users/shubhadeepbhattacharya/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                       Quantity       Total
# Item Desc
# NIRVANA HOOKAH SINGLE                     8686  2953134.60
# CAPPUCCINO                                7144   550251.99
# MINT FLAVOUR SINGLE                       6019  1840501.00
# GREAT LAKES SHAKE                         5914   843122.11
# SAMBUCA                                   4765  2291058.00
# POUTINE WITH FRIES                        3741   580284.11
# QUA  MINERAL WATER(1000ML)                3633   224695.81
# JR.CHL AVALANCHE                          3446   713565.60
# CARLSBERG                                 3380   538802.08
# CALCUTTA MINT                             3339  1640860.40
# ...

# %%
## most expensive items on the menu
data.groupby(data['Item Desc'])['Rate'].mean().sort_values(ascending=False).head(50)
# Out:
# Item Desc
# GOSSIPS CHARD AUS (BTL)           2100.000000
# MATEUS ROSE PORTUGAL(BTL)         2000.000000
# 2 OCEAN PINOTAGE (BTL)            1900.000000
# MAISON PIERRE SAUV MARSAN         1700.000000
# J.PCHENET SPARKLING ROSE (BTL)    1700.000000
# FLAVOR 1000 GMS                   1470.000000
# HOEGAARDEN LTR MUGS (2+1)         1300.000000
# STELLA 1LTR 2+1                   1300.000000
# SCHNEIDER BUCKET - 6              1200.000000
# SULA BRUT (BTL)                   1200.000000
# VLN CAB SAUV CLASIQ (BTL)         1025.000000
# UNLIMITED BEER                     999.000000
# 4 SEASONS CLAS SAUV(BTL)           900.000000
# 1+1 BTL4 SEASON WHITE              900.000000
# B1G1 4SEASON CLAS SAUV(BTL)        900.000000
# SULA BLUSH ZINFANDEL (BTL)         900.000000
# 1+1 WINE BOTTLE                    851.000000
# RED SANGRIA (CARAFE) áááááááá      814.583333
# FLAVOUR 500 GMS                    810.000000
# WHITE SANGRIA (CARAFE)áááááááá     808.333333
# ...

# %%
## the least expensive products on the menu
data.groupby(data['Item Desc'])['Rate'].mean().sort_values(ascending=True).head(50)
# Out:
# Item Desc
# MOTHERS DAY SPL                          0.010000
# CUTTING GLASS                           12.000000
# ADD BUTTERED TOAST                      15.000000
# ADD ON S                                15.329815
# MUSHROOM                                20.000000
# BUTTERED TOASTS                         20.000000
# CHEDDAR CHEESE                          20.000000
# ADD CARAMEL FLAVOUR                     25.000000
# ADD VANILLA FLAVOUR                     25.000000
# ADD COTTAGE CHEESE                      25.000000
# ADD HAZELNUT FLAVOUR                    25.000000
# ADD IRISH CREAM FLAVOUR                 25.000000
# MUSHROOM & CORN                         25.000000
# ADD CINNAMON FLAVOUR                    25.000000
# ADD WHIPPED CREAM                       29.057971
# CHICKEN SALAMI                          30.000000
# CHICKEN SAUSAGE                         30.000000
# CHOCOLATE ICECREAM                      30.000000
# ADD CHICKEN BACON                       30.000000
# ...

# %%
data.Category.nunique()
# Out:
# 9

# %%
data.Category.unique()
# Out:
# array(['BEVERAGE', 'FOOD', 'LIQUOR', 'MERCHANDISE', 'TOBACCO', 'MISC',
#        'WINES', 'LIQUOR & TOBACCO', 'LIQUOR '], dtype=object)

# %%
data.groupby('Category')['Quantity'].sum()
# Out:
# Category
# BEVERAGE            50637
# FOOD                62141
# LIQUOR              10283
# LIQUOR                  1
# LIQUOR & TOBACCO       63
# MERCHANDISE           551
# MISC                 1385
# TOBACCO             37384
# WINES                1074
# Name: Quantity, dtype: int64

# %%
## 7 categories - L&T is a composite category, and Liquor repeats itself

# %%
data.groupby('Category')['Quantity'].sum().plot(kind='bar')

# %%
data.groupby('Category')['Quantity'].sum().plot(kind='pie', figsize=(10,10))

# %%
## Category wise split of Earnings / Sales proceeds

# %%
data.groupby('Category')['Total'].sum()
# Out:
# Category
# BEVERAGE            5.510239e+06
# FOOD                9.952728e+06
# LIQUOR              2.112397e+06
# LIQUOR              1.050000e+03
# LIQUOR & TOBACCO    4.256152e+04
# MERCHANDISE         1.200740e+05
# MISC                2.068581e+05
# TOBACCO             1.450708e+07
# WINES               3.529116e+05
# Name: Total, dtype: float64

# %%
data.groupby('Category')['Total'].sum().plot(kind='bar')

# %%
data[data['Category']=='TOBACCO']['Total'].sum()
# Out:
# 14507075.74

# %%
data['Total'].sum()
# Out:
# 32805895.27

# %%
14507075.74/32805895.27*100
# Out:
# 44.2209414515393

# %% [markdown]
# Tobacco - highest earning category, 44% of total sales revenues

# %%
data[data.Category=='BEVERAGE']
# Out:
#              Date Bill Number                        Item Desc      Time  \
# 0      2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11
# 1      2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11
# 2      2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35
# 3      2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55
# 4      2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18
# ...           ...          ...                             ...       ...
# 145606 2010-12-31     G0517902  VANILLA LITE SHAKE              17:30:52
# 145756 2010-06-08     G0480993  WHAT A MELON                    01:09:11
# 145757 2010-05-10     G0476412  WHAT A MELON                    19:02:39
# 145758 2010-05-26     G0478941  WHAT A MELON                    00:56:44
# 145759 2010-04-29     G0474699  WHAT A MELON                    17:05:33
#
#         Quantity   Rate     Tax  Discount   Total  Category
# ...

# %%
data[data.Category=='LIQUOR']
# Out:
#              Date Bill Number                        Item Desc      Time  \
# 258    2010-04-01     N0027835  CARLSBERG                       13:37:13
# 259    2010-04-01     N0027836  CARLSBERG                       13:55:17
# 260    2010-04-01     N0027837  TUBORG                          15:30:42
# 261    2010-04-01     N0027838  TUBORG                          16:16:40
# 262    2010-04-01     N0027840  CARLSBERG                       18:57:51
# ...           ...          ...                             ...       ...
# 145825 2010-05-22     N0028716  ZINZI WHITE  (GLS)              21:43:55
# 145826 2010-04-27     N0028343  ZINZI WHITE  (GLS)              20:52:11
# 145827 2010-05-28     N0028835  ZINZI WHITE  (GLS)              01:03:37
# 145828 2010-04-30     N0028399  ZINZI WHITE  (GLS)              23:44:37
# 145829 2010-07-09     N0029472  ZINZI WHITE (BTL)               00:31:51
#
#         Quantity   Rate     Tax  Discount   Total Category
# ...

# %%
data[data.Category=='WINES']['Total'].sum()
# Out:
# 352911.62

# %%
data[data.Category=='LIQUOR & TOBACCO']
# Out:
#              Date Bill Number                        Item Desc      Time  \
# 53088  2011-03-09     N0033683  2 DOM BEER + 1SPL SHEESHA       22:50:05
# 57949  2011-03-13     G0531015  BEER HOOKAH                     18:25:52
# 57950  2011-03-13     G0531091  BEER HOOKAH                     23:46:55
# 86272  2011-03-19     G0532021  BEER HOOKAH                     23:15:15
# 90761  2011-02-20     N0033387  2 DOM BEER + 1SPL SHEESHA       18:27:43
# 90762  2011-02-20     N0033391  2 DOM BEER + 1SPL SHEESHA       20:42:31
# 91170  2011-03-20     G0532205  BEER HOOKAH                     00:36:15
# 95432  2011-02-21     N0033404  4 DOM BEER + 1SPL SHEESHA       13:00:14
# 100044 2011-02-22     N0033421  4 DOM BEER + 1SPL SHEESHA       17:23:36
# 100045 2011-02-22     N0033424  2 DOM BEER + 1SPL SHEESHA       18:06:29
# 104667 2011-02-23     N0033449  2 DOM BEER + 1SPL SHEESHA       01:34:58
# 104668 2011-02-23     N0033442  2 DOM BEER + 1SPL SHEESHA       19:30:18
# ...

# %%
## Liquor and Tobacco appears to be a Combo category

# %%
## Analysing Total (Sales Earnings) and Quantity at the Bill Level

# %%
data.groupby(data['Bill Number ']).count()
# Out:
#               Date  Item Desc  Time  Quantity  Rate  Tax  Discount  Total  \
# Bill Number
# G0470109         1          1     1         1     1    1         1      1
# G0470110         1          1     1         1     1    1         1      1
# G0470111         4          4     4         4     4    4         4      4
# G0470112         2          2     2         2     2    2         2      2
# G0470113         1          1     1         1     1    1         1      1
# ...            ...        ...   ...       ...   ...  ...       ...    ...
# N0034042         2          2     2         2     2    2         2      2
# N0034043         1          1     1         1     1    1         1      1
# N0034044         1          1     1         1     1    1         1      1
# N0034045         1          1     1         1     1    1         1      1
# N0034046         1          1     1         1     1    1         1      1
#
#               Category
# Bill Number
# G0470109             1
# ...

# %%
plt.figure(figsize=(20,8))
sns.distplot(data.groupby('Bill Number ').sum()['Total'])

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data.groupby('Bill Number ').sum()['Total'], color = 'Salmon')

# %%
data.groupby('Bill Number ').sum()['Total'].describe()
# Out:
# count    69982.000000
# mean       468.776189
# std        348.423861
# min          1.260000
# 25%        272.250000
# 50%        391.460000
# 75%        594.000000
# max      14231.250000
# Name: Total, dtype: float64

# %%
data.groupby('Bill Number ').sum()['Quantity'].describe()
# Out:
# count    69982.000000
# mean         2.336587
# std          1.799691
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         64.000000
# Name: Quantity, dtype: float64

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data.groupby('Bill Number ').sum()['Quantity'], color = 'Salmon')

# %%
594*1.25
# Out:
# 742.5

# %%
data.describe()
# Out:
#             Quantity           Rate            Tax       Discount  \
# count  145830.000000  145830.000000  145830.000000  145830.000000
# mean        1.121299     161.782259      48.929061       0.095079
# std         0.477237     102.244631      40.272851       3.720735
# min         1.000000       0.010000       0.000000       0.000000
# 25%         1.000000      95.000000      22.560000       0.000000
# 50%         1.000000     125.000000      32.060000       0.000000
# 75%         1.000000     225.000000      72.000000       0.000000
# max        30.000000    2100.000000    2731.250000     825.000000
#
#                Total
# count  145830.000000
# mean      224.959852
# std       164.960776
# min         0.010000
# 25%       117.560000
# 50%       167.060000
# 75%       315.000000
# max     14231.250000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145830 entries, 0 to 145829
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          145830 non-null  datetime64[ns]
#  1   Bill Number   145830 non-null  object
#  2   Item Desc     145830 non-null  object
#  3   Time          145830 non-null  object
#  4   Quantity      145830 non-null  int64
#  5   Rate          145830 non-null  float64
#  6   Tax           145830 non-null  float64
#  7   Discount      145830 non-null  float64
#  8   Total         145830 non-null  float64
#  9   Category      145830 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 11.1+ MB

# %%
data.duplicated().sum()
# Out:
# 680

# %%
data[data.duplicated()]
# Out:
#              Date Bill Number                        Item Desc      Time  \
# 198    2010-04-01     G0470211  B.M.T. PANINI                   19:42:27
# 199    2010-04-01     G0470211  B.M.T. PANINI                   19:42:27
# 244    2010-04-01     G0470270  B.M.T. PANINI                   00:08:20
# 551    2010-05-01     G0474965  PHILLYCREAM CHEESE &CHILLY PAN  13:33:51
# 588    2010-05-01     G0475009  B.M.T. PANINI                   17:12:21
# ...           ...          ...                             ...       ...
# 144615 2010-10-31     G0506562  DOPPIO                          19:08:48
# 144727 2010-10-31     G0506566  CHEESE CAKE OF THE WEEK         19:20:52
# 145129 2010-12-31     G0517963  CAPPUCCINO                      20:50:13
# 145255 2010-12-31     G0517869  PHILLYCREAM CHEESE &CHILLY PAN  15:12:41
# 145315 2010-12-31     G0518126  PHILLYCREAM CHEESE &CHILLY PAN  05:02:24
#
#         Quantity   Rate    Tax  Discount   Total  Category
# ...

# %%
data.iloc[190:200]
# Out:
#           Date Bill Number                              Item Desc      Time  \
# 190 2010-04-01     G0470200  GREAT LAKES SHAKE                     19:04:09
# 191 2010-04-01     G0470201        COUNTRY ROAST CHICKEN PANINI    19:08:22
# 192 2010-04-01     G0470201        NON-VEG CLUB WRAP               19:08:22
# 193 2010-04-01     G0470201        JR.CHL AVALANCHE                19:08:22
# 194 2010-04-01     G0470203        JR.CHL AVALANCHE                19:26:10
# 195 2010-04-01     G0470206        B.M.T. PANINI                   19:31:28
# 196 2010-04-01     G0470209        B.M.T. PANINI                   19:37:12
# 197 2010-04-01     G0470211        B.M.T. PANINI                   19:42:27
# 198 2010-04-01     G0470211        B.M.T. PANINI                   19:42:27
# 199 2010-04-01     G0470211        B.M.T. PANINI                   19:42:27
#
#      Quantity   Rate    Tax  Discount   Total Category
# 190         1  110.0  26.13       0.0  136.13     FOOD
# ...

# %% [markdown]
# Duplicates detected, but will be ignored for this exercise

# %%
## analysing the most popular items / bestsellers

# %%
data['Item Desc'].value_counts().head(50)
# Out:
# NIRVANA HOOKAH SINGLE                   8553
# MINT FLAVOUR SINGLE                     5817
# CAPPUCCINO                              5495
# GREAT LAKES SHAKE                       4895
# SAMBUCA                                 4425
# POUTINE WITH FRIES                      3464
# QUA  MINERAL WATER(1000ML)              3331
# CALCUTTA MINT                           3318
# JR.CHL AVALANCHE                        3314
# B.M.T. PANINI                           2724
# GREEN APPLE FLAVOUR SINGLE              2528
# MOROCCAN MINT TEA                       2257
# N R G  HOOKAH                           2252
# MASALA CHAI CUTTING                     2234
# LEMON ICED TEA                          2196
# CAFFE LATTE                             2110
# BERRY BLAST                             2031
# OREO COOKIE SHAKE                       1998
# SILVER APPLE SINGLE                     1971
# PHILLYCREAM CHEESE &CHILLY PAN          1898
# RED BULL ENERGY DRINK                   1860
# ...

# %%
data['Item Desc'].value_counts(normalize=True).head(50)
# Out:
# NIRVANA HOOKAH SINGLE                   0.058650
# MINT FLAVOUR SINGLE                     0.039889
# CAPPUCCINO                              0.037681
# GREAT LAKES SHAKE                       0.033566
# SAMBUCA                                 0.030344
# POUTINE WITH FRIES                      0.023754
# QUA  MINERAL WATER(1000ML)              0.022842
# CALCUTTA MINT                           0.022753
# JR.CHL AVALANCHE                        0.022725
# B.M.T. PANINI                           0.018679
# GREEN APPLE FLAVOUR SINGLE              0.017335
# MOROCCAN MINT TEA                       0.015477
# N R G  HOOKAH                           0.015443
# MASALA CHAI CUTTING                     0.015319
# LEMON ICED TEA                          0.015059
# CAFFE LATTE                             0.014469
# BERRY BLAST                             0.013927
# OREO COOKIE SHAKE                       0.013701
# SILVER APPLE SINGLE                     0.013516
# ...

# %%
8553/145830
# Out:
# 0.058650483439621474

# %% [markdown]
# the most popular menu item has been ordered in 5% of the transactions

# %%
705/145830
# Out:
# 0.0048343962147706235

# %%
## NOTE: for Market Basket Analysis: support cut off can be at 0.004 to feature at least the top 50 items

# %%
## the least popular items

# %%
data['Item Desc'].value_counts().tail(55)
# Out:
# STELLA ARTOIS                           2
# AVALANCHE BOWL                          1
# MANDALA VALLEY RED ZINFANDEL(G          1
# CUTTING GLASS                           1
# SILVER STYLER 1.0                       1
# BEACH GREEN                             1
# KITSCH BLUE                             1
# 2 AXE TWIST                             1
# ADD BUTTERED TOAST                      1
# MOCAFE HOT CHOCOLATE(SF)                1
# ETCHED LEAF TLIGHT HOLDER               1
# DECAFFINATE COFFEE FRAPPE               1
# GOSSIPS CHARD AUS (BTL)                 1
# B1G1 4SEASON CLAS SAUV(GLS)             1
# KITSCH PINK                             1
# MANDALA VALLEY CHENIN BLANC(GL          1
# MODEL-P (IRON ASHTRAY)                  1
# INDIA KINGS OCEAN BLUE                  1
# 4 SEASONS CLAS SYRAH(BTL)               1
# SULA CHENIN BLANC (BTL)                 1
# PARTY CHARGES @ 500/-                   1
# GOLD FLAKE ULTRA LIGHTS(20)             1
# ...

# %% [markdown]
# 54 items in the dataset have been ordered only once.

# %%
## analyse least popular
data.groupby(['Item Desc', 'Category']).sum()[['Quantity','Total']].sort_values(by='Quantity').head(54)
# Out:
#                                                   Quantity    Total
# Item Desc                            Category
# ZINZI WHITE (BTL)                    LIQUOR              1   882.00
# GRAPPO SHEESHA                       MISC                1   594.00
# GREAT LAKES MUG SINGLE               MERCHANDISE         1   159.75
# GUERILLA COOL                        MERCHANDISE         1   294.75
# HOEGAARDEN GLS (2+1)                 MISC                1   918.75
# HOEGAARDEN LTR MUGS (2+1)            MISC                1  1706.25
# INDIA KINGS OCEAN BLUE               TOBACCO             1   109.80
# GOSSIPS CHARD AUS (BTL)              WINES               1  2756.25
# AL SIKANDARI HOOKAH DOUBLE           TOBACCO             1   455.40
# KITSCH BLUE                          MERCHANDISE         1   294.75
# BENARAS BLUE                         MERCHANDISE         1   394.88
# KONKAN STRIPE                        MERCHANDISE         1   294.75
# ...

# %%
data.groupby(['Item Desc', 'Category']).sum()[['Quantity','Total']].sort_values(by='Quantity').head(54).groupby('Category').count()
# Out:
#              Quantity  Total
# Category
# BEVERAGE            4      4
# FOOD                1      1
# LIQUOR              1      1
# LIQUOR              1      1
# MERCHANDISE        21     21
# MISC               13     13
# TOBACCO             4      4
# WINES               9      9

# %%
data.groupby(['Item Desc', 'Category']).sum()[['Quantity','Total']].sort_values(by='Quantity').head(100).groupby('Category').count()
# Out:
#                   Quantity  Total
# Category
# BEVERAGE                 5      5
# FOOD                     6      6
# LIQUOR                   2      2
# LIQUOR                   1      1
# LIQUOR & TOBACCO         2      2
# MERCHANDISE             40     40
# MISC                    23     23
# TOBACCO                  7      7
# WINES                   14     14

# %%
data.groupby(['Item Desc', 'Category']).sum()['Quantity'].sort_values().head(100).groupby('Category').count().plot(kind='bar')

# %%
## analyse least popular
data.groupby(['Item Desc', 'Category']).sum()[['Quantity','Total']].sort_values(by='Total').head(50)
# Out:
#                                                   Quantity   Total
# Item Desc                            Category
# MOTHERS DAY SPL                      FOOD                5    0.05
# ADD BUTTERED TOAST                   FOOD                1   18.56
# CUTTING GLASS                        MERCHANDISE         2   27.00
# DIP BOWL                             MERCHANDISE         1   67.50
# MUGS - PLAIN COLOUR                  MERCHANDISE         1   75.38
# MOCAFE HOT CHOCOLATE(SF)             BEVERAGE            1   80.44
# GOLD FLAKE ULTRA LIGHTS(20)          TOBACCO             1   87.60
# CH WRAPPING PAPER                    MERCHANDISE         2   90.00
# DECAFFINATE COFFEE FRAPPE            BEVERAGE            1   92.81
# CLASSIC REGULAR                      TOBACCO             1   93.60
# INDIA KINGS OCEAN BLUE               TOBACCO             1  109.80
# ADD GROUND MEAT                      MISC                3  111.39
# ...

# %%
data.groupby(['Item Desc', 'Category']).sum()['Total'].sort_values().head(100).groupby('Category').count().plot(kind='bar')

# %%
data[data['Category']=='MISC']['Item Desc'].unique()
# Out:
# array(['1 AXE TWIST                   ', 'ADD CHICKEN BACON             ',
#        'ADD GROUND MEAT               ', 'ADD HERB ROAST CHICKEN        ',
#        'ADD ON S                      ', 'ADD POTATO WEDGES             ',
#        'ADD TRADITIONAL MEAT FEAST    ', 'DARK RUM (SM)                 ',
#        'ENG BREAKFAST TEA             ', 'FISH FINGER                   ',
#        'GIN (SM)                      ', 'GNOCCHI CON POMMODORO         ',
#        'GRAPPO SHEESHA                ', 'GREEK GYROS CRUSTINI          ',
#        'GUAVA                         ', 'HOEGAARDEN GLS (2+1)          ',
#        'HOEGAARDEN LTR MUGS (2+1)     ', 'HOTDOG WRAP                   ',
#        'ICE BERG SHEESHA              ', 'ITALIAN CAPONATA PANINO       ',
#        'JAPANESE YAKITORI WRAP        ', 'KF DRAFT MUG                  ',
#        'LEMON INFUSED CHAR GRILLED VEG', 'M & M SHAKE                   ',
# ...

# %%
data[data['Item Desc']=='JAPANESE YAKITORI WRAP        ']
# Out:
#             Date Bill Number                        Item Desc      Time  \
# 73081 2010-05-01     G0475122  JAPANESE YAKITORI WRAP          00:24:47
# 73082 2010-07-01     G0484819  JAPANESE YAKITORI WRAP          18:07:37
# 73083 2010-07-01     G0484834  JAPANESE YAKITORI WRAP          18:48:53
# 73084 2010-08-01     G0490462  JAPANESE YAKITORI WRAP          19:12:03
# 73085 2010-10-01     G0501514  JAPANESE YAKITORI WRAP          23:59:03
# ...          ...          ...                             ...       ...
# 73919 2010-06-28     G0484307  JAPANESE YAKITORI WRAP          20:09:04
# 73920 2010-06-29     G0484483  JAPANESE YAKITORI WRAP          19:11:26
# 73921 2010-07-30     G0490048  JAPANESE YAKITORI WRAP          18:41:38
# 73922 2010-10-30     G0506403  JAPANESE YAKITORI WRAP          21:18:03
# 73923 2010-12-31     G0517875  JAPANESE YAKITORI WRAP          15:28:50
#
#        Quantity   Rate    Tax  Discount   Total Category
# ...

# %%
## visualise:
data['Item Desc'].value_counts().head(50).plot(kind='bar', figsize=(20,8))

# %%
data.columns
# Out:
# Index(['Date', 'Bill Number ', 'Item Desc', 'Time', 'Quantity', 'Rate', 'Tax',
#        'Discount', 'Total', 'Category'],
#       dtype='object')

# %%
## assessing Bills by Order Value (Total)

# %%
data.groupby('Bill Number ').sum().sort_values(by='Quantity', ascending=False).head(50)
# Out:
#               Quantity    Rate      Tax  Discount     Total
# Bill Number
# G0481424            64  2125.0  2220.95       0.0  11415.95
# G0518491            58  2000.0  1280.96    2311.5   8985.96
# G0516596            52  1915.0  1732.71       0.0   8602.71
# G0508496            45  1690.0  1185.15       0.0   6175.15
# G0527570            41  3350.0  1636.84       0.0   8111.84
# G0490530            36  2490.0   859.33       0.0   4399.33
# G0496879            32    30.0   114.01       0.0    594.01
# G0495644            32  1660.0   632.96       0.0   3297.96
# G0489943            30  2645.0   857.39       0.0   4467.39
# G0522644            26   980.0   812.25       0.0   4232.25
# G0518006            26  2865.0   800.39       0.0   4170.39
# G0533704            25  2295.0   903.71       0.0   4708.71
# G0530430            25  1815.0   866.51       0.0   4306.51
# G0526679            25  2585.0   839.60       0.0   4374.60
# ...

# %% [markdown]
# At the Bill level, the largest order had 64 units.

# %%
data.sort_values(by='Quantity', ascending=False).head(50)
# Out:
#              Date Bill Number                              Item Desc  \
# 4780   2010-09-04     G0496879        ADD ON S
# 118156 2010-12-25     G0516596        LEMON ICED TEA
# 94768  2011-01-25     G0522713        PARTY CHARGES @ 500/-
# 20620  2010-11-06     N0031305        TUBORG
# 98693  2010-11-21     N0031577        CARLSBERG
# 118462 2010-12-25     N0032310        CARLSBERG
# 46862  2011-01-05     N0032625        TUBORG
# 91453  2010-04-20     N0028179        CARLSBERG
# 124303 2011-02-27     N0033526        CARLSBERG
# 89821  2010-12-19     N0032133        TUBORG
# 30440  2010-10-09     N0030851        KF DRAUGHT (1LTR)
# 90489  2011-02-20     G0527570        LEMON ICED TEA
# 17074  2010-11-05     N0031266        CARLSBERG
# 50210  2011-02-07     N0033159        CARLSBERG
# 56290  2011-02-12     N0033255        BUDWEISER
# 51137  2011-01-08     N0032697        CARLSBERG
# 112474 2010-10-24     N0031090        STELLA ARTOIS (GLS)
# ...

# %%
data.groupby('Bill Number ').sum().sort_values(by='Total', ascending=False).head(50)
# Out:
#               Quantity    Rate      Tax  Discount     Total
# Bill Number
# G0522713            23   500.0  2731.25       0.0  14231.25
# G0481424            64  2125.0  2220.95       0.0  11415.95
# G0518491            58  2000.0  1280.96    2311.5   8985.96
# G0516596            52  1915.0  1732.71       0.0   8602.71
# G0527570            41  3350.0  1636.84       0.0   8111.84
# G0508496            45  1690.0  1185.15       0.0   6175.15
# N0034025             4  2750.0  1265.63       0.0   5315.63
# N0033934            14   525.0  1257.82       0.0   5282.82
# N0033392            10   400.0  1250.00       0.0   5250.00
# N0030048             5  1300.0  1024.63       0.0   4874.63
# G0533714            15  2100.0   999.26       0.0   4859.26
# G0514006            17  1395.0  1065.07       0.0   4820.07
# G0533702            22  2920.0  1016.76       0.0   4776.76
# G0533704            25  2295.0   903.71       0.0   4708.71
# ...

# %%
## TIME SERIES ANALYSIS

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145830 entries, 0 to 145829
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          145830 non-null  datetime64[ns]
#  1   Bill Number   145830 non-null  object
#  2   Item Desc     145830 non-null  object
#  3   Time          145830 non-null  object
#  4   Quantity      145830 non-null  int64
#  5   Rate          145830 non-null  float64
#  6   Tax           145830 non-null  float64
#  7   Discount      145830 non-null  float64
#  8   Total         145830 non-null  float64
#  9   Category      145830 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 11.1+ MB

# %%
data.Time.describe()
# Out:
# count       145830
# unique       36200
# top       22:25:36
# freq            33
# Name: Time, dtype: object

# %%
data.Time.head(50)
# Out:
# 0     13:15:11
# 1     13:15:11
# 2     13:17:35
# 3     13:19:55
# 4     01:20:18
# 5     01:20:18
# 6     13:21:34
# 7     13:21:34
# 8     01:29:38
# 9     01:29:46
# 10    01:29:46
# 11    01:29:46
# 12    13:36:33
# 13    13:42:05
# 14    13:42:05
# 15    14:02:15
# 16    14:02:35
# 17    14:21:32
# 18    14:53:24
# 19    14:54:32
# 20    15:08:58
# 21    15:08:58
# 22    15:09:07
# 23    15:39:18
# 24    15:48:25
# 25    16:06:01
# 26    16:07:55
# 27    16:15:45
# 28    16:15:50
# 29    16:16:40
# 30    16:25:25
# 31    16:25:25
# 32    16:25:25
# 33    16:45:12
# 34    16:46:08
# 35    16:50:57
# 36    16:51:48
# 37    16:58:33
# 38    16:58:33
# 39    16:59:11
# 40    16:59:11
# 41    17:10:45
# 42    17:10:45
# 43    17:16:18
# 44    17:22:20
# 45    17:33:33
# 46    17:43:59
# 47    18:04:09
# 48    18:05:34
# 49    18:09:04
# Name: Time, dtype: object

# %%
from datetime import datetime

# %%
# Load dataset

data_timeline = pd.read_excel('Cafe_Data_MRA.xlsx',  parse_dates = [['Date', 'Time']],index_col=0)

# %%
data_timeline
# Out:
#                     Bill Number                        Item Desc  Quantity  \
# Date_Time
# 2010-04-01 13:15:11     G0470115  QUA  MINERAL WATER(1000ML)             1
# 2010-04-01 13:15:11     G0470115  MONSOON MALABAR (AULAIT)               1
# 2010-04-01 13:17:35     G0470116  MASALA CHAI CUTTING                    1
# 2010-04-01 13:19:55     G0470117  QUA  MINERAL WATER(1000ML)             1
# 2010-04-01 01:20:18     G0470283  MOROCCAN MINT TEA                      1
# ...                          ...                             ...       ...
# 2010-05-22 21:43:55     N0028716  ZINZI WHITE  (GLS)                     2
# 2010-04-27 20:52:11     N0028343  ZINZI WHITE  (GLS)                     2
# 2010-05-28 01:03:37     N0028835  ZINZI WHITE  (GLS)                     3
# 2010-04-30 23:44:37     N0028399  ZINZI WHITE  (GLS)                     1
# 2010-07-09 00:31:51     N0029472  ZINZI WHITE (BTL)                      1
#
# ...

# %%
data_timeline['Total'].plot(kind='line', figsize=(20,8))

# %%
data_timeline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145830 entries, 2010-04-01 13:15:11 to 2010-07-09 00:31:51
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Bill Number   145830 non-null  object
#  1   Item Desc     145830 non-null  object
#  2   Quantity      145830 non-null  int64
#  3   Rate          145830 non-null  float64
#  4   Tax           145830 non-null  float64
#  5   Discount      145830 non-null  float64
#  6   Total         145830 non-null  float64
#  7   Category      145830 non-null  object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 10.0+ MB

# %%
plt.plot(data_timeline['Total'][:5])

# %%
plt.figure(figsize=(20,8))
plt.plot(data_timeline['Total'])

# %% [markdown]
# the timeline gets warped because of the Time column - it needs to be treated

# %%
data_timeline.sort_values(by='Date_Time')
# Out:
#                     Bill Number                              Item Desc  \
# Date_Time
# 2010-04-01 00:08:20     G0470270  GREAT LAKES SHAKE
# 2010-04-01 00:08:20     G0470270        KIT KAT SHAKE
# 2010-04-01 00:08:20     G0470270        COUNTRY LEMONADE
# 2010-04-01 00:08:20     G0470270        B.M.T. PANINI
# 2010-04-01 00:08:20     G0470270        B.M.T. PANINI
# ...                          ...                                   ...
# 2011-03-31 23:38:55     G0533877        GREEN APPLE FLAVOUR SINGLE
# 2011-03-31 23:42:45     G0533878        RED BULL ENERGY DRINK
# 2011-03-31 23:42:45     G0533878        SAMBUCA
# 2011-03-31 23:42:45     G0533878        NIRVANA HOOKAH SINGLE
# 2011-03-31 23:59:51     G0533879        3 RED BULL
#
#                      Quantity   Rate     Tax  Discount   Total  Category
# Date_Time
# 2010-04-01 00:08:20         2  110.0   52.25       0.0  272.25      FOOD
# 2010-04-01 00:08:20         1  135.0   32.06       0.0  167.06      FOOD
# ...

# %%
data_time_sorted = data_timeline.sort_values(by='Date_Time')

# %%
data_time_sorted.plot(figsize=(20,8))

# %%
plt.figure(figsize=(20,8))
plt.plot(data_time_sorted['Total'])

# %%
data_time_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145830 entries, 2010-04-01 00:08:20 to 2011-03-31 23:59:51
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Bill Number   145830 non-null  object
#  1   Item Desc     145830 non-null  object
#  2   Quantity      145830 non-null  int64
#  3   Rate          145830 non-null  float64
#  4   Tax           145830 non-null  float64
#  5   Discount      145830 non-null  float64
#  6   Total         145830 non-null  float64
#  7   Category      145830 non-null  object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 10.0+ MB

# %%
## checking if sorting addresses the issue. CLosely looking at the first set of observations:

# %%
plt.figure(figsize=(20,8))
plt.plot(data_time_sorted[0:100].Total)

# %%
plt.figure(figsize=(20,8))
plt.plot(data_time_sorted[0:500].Quantity)

# %%
data_c = data.copy()

# %%
data_c.head()
# Out:
#         Date Bill Number                        Item Desc      Time  Quantity  \
# 0 2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11         1
# 1 2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11         1
# 2 2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35         1
# 3 2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55         1
# 4 2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18         1
#
#     Rate    Tax  Discount   Total  Category
# 0   50.0  11.88       0.0   61.88  BEVERAGE
# 1  100.0  23.75       0.0  123.75  BEVERAGE
# 2   40.0   9.50       0.0   49.50  BEVERAGE
# 3   50.0  11.88       0.0   61.88  BEVERAGE
# 4   45.0  10.69       0.0   55.69  BEVERAGE

# %%
## adding day of week - to assess pattern for weekdays

# %%
data_c['Day_of_Week'] = data_c['Date'].dt.day_name()

# %%
data_c.head()
# Out:
#         Date Bill Number                        Item Desc      Time  Quantity  \
# 0 2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11         1
# 1 2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11         1
# 2 2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35         1
# 3 2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55         1
# 4 2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18         1
#
#     Rate    Tax  Discount   Total  Category Day_of_Week
# 0   50.0  11.88       0.0   61.88  BEVERAGE    Thursday
# 1  100.0  23.75       0.0  123.75  BEVERAGE    Thursday
# 2   40.0   9.50       0.0   49.50  BEVERAGE    Thursday
# 3   50.0  11.88       0.0   61.88  BEVERAGE    Thursday
# 4   45.0  10.69       0.0   55.69  BEVERAGE    Thursday

# %%
# plotting after removing one outlier value
plt.figure(figsize=(20,20))
sns.boxplot(x='Day_of_Week', y = 'Total', data=data_c.drop(94768))

# %%
##

# %%
fig, ax = plt.subplots(figsize=(20,8))
sns.boxplot(data_time_sorted.index.month, data_time_sorted['Total'], ax=ax,whis=1.5)
plt.grid();

# %%
fig, ax = plt.subplots(figsize=(20,8))
sns.boxplot(data_time_sorted.index.weekday, data_time_sorted['Total'], ax=ax,whis=1.5)
plt.grid();

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.boxplot(data_time_sorted.index.hour, data_time_sorted['Total'], ax=ax,whis=1.5)
plt.grid();

# %% [markdown]
# Note: Box plots do not clearly show the trend in the above cases, use alternative visualisation - Tableau

# %%
## quarterly plot

# %%
df_quarterly_sum = data_time_sorted['Total'].resample('Q').sum()
df_quarterly_sum.head()
# Out:
# Date_Time
# 2010-06-30    7.155254e+06
# 2010-09-30    8.058854e+06
# 2010-12-31    8.840031e+06
# 2011-03-31    8.751757e+06
# Freq: Q-DEC, Name: Total, dtype: float64

# %%
df_quarterly_sum.plot(figsize=(20,8));
plt.grid()

# %%
## monthly plot

# %%
df_monthly_sum = data_time_sorted['Total'].resample('M').sum()
df_monthly_sum.head()
# Out:
# Date_Time
# 2010-04-30    2442077.08
# 2010-05-31    2360411.46
# 2010-06-30    2352765.05
# 2010-07-31    2728633.27
# 2010-08-31    2832577.56
# Freq: M, Name: Total, dtype: float64

# %%
df_monthly_sum.plot(figsize=(20,8));
plt.grid()

# %%
df_monthly_mean = data_time_sorted['Total'].resample('M').mean()
df_monthly_mean.head()
# Out:
# Date_Time
# 2010-04-30    218.628208
# 2010-05-31    219.511900
# 2010-06-30    216.764792
# 2010-07-31    213.591645
# 2010-08-31    213.071879
# Freq: M, Name: Total, dtype: float64

# %%
df_monthly_mean.plot(figsize=(20,8));
plt.grid()

# %%
data_time_sorted.head()
# Out:
#                     Bill Number                              Item Desc  \
# Date_Time
# 2010-04-01 00:08:20     G0470270  GREAT LAKES SHAKE
# 2010-04-01 00:08:20     G0470270        KIT KAT SHAKE
# 2010-04-01 00:08:20     G0470270        COUNTRY LEMONADE
# 2010-04-01 00:08:20     G0470270        B.M.T. PANINI
# 2010-04-01 00:08:20     G0470270        B.M.T. PANINI
#
#                      Quantity   Rate    Tax  Discount   Total  Category
# Date_Time
# 2010-04-01 00:08:20         2  110.0  52.25       0.0  272.25      FOOD
# 2010-04-01 00:08:20         1  135.0  32.06       0.0  167.06      FOOD
# 2010-04-01 00:08:20         1   85.0  20.19       0.0  105.19  BEVERAGE
# 2010-04-01 00:08:20         1  105.0  24.94       0.0  129.94      FOOD
# 2010-04-01 00:08:20         1  105.0  24.94       0.0  129.94      FOOD

# %%
dts_q = data_time_sorted['Quantity']

# %%
dts_t = data_time_sorted['Total']

# %%
dts_q.head()
# Out:
# Date_Time
# 2010-04-01 00:08:20    2
# 2010-04-01 00:08:20    1
# 2010-04-01 00:08:20    1
# 2010-04-01 00:08:20    1
# 2010-04-01 00:08:20    1
# Name: Quantity, dtype: int64

# %%
## daily plot

# %%
df_daily_sum = data_time_sorted['Total'].resample('D').sum()
df_daily_sum.head()
# Out:
# Date_Time
# 2010-04-01     77066.51
# 2010-04-02     88423.17
# 2010-04-03    140314.76
# 2010-04-04     86284.74
# 2010-04-05     75674.14
# Freq: D, Name: Total, dtype: float64

# %%
df_daily_sum.plot(figsize=(20,8));
plt.grid()

# %%
## date with the highest sales revenue
df_daily_sum[df_daily_sum == df_daily_sum.max()]
# Out:
# Date_Time
# 2010-12-31    249995.13
# Freq: D, Name: Total, dtype: float64

# %%
## date with the least sales
df_daily_sum[df_daily_sum == df_daily_sum.min()]
# Out:
# Date_Time
# 2010-05-04    47176.66
# Freq: D, Name: Total, dtype: float64

# %%
df_daily_sum.describe()
# Out:
# count       365.000000
# mean      89879.165123
# std       18557.713774
# min       47176.660000
# 25%       78232.060000
# 50%       87034.640000
# 75%       99192.940000
# max      249995.130000
# Name: Total, dtype: float64

# %%
df_weekly_sum = data_time_sorted['Quantity'].resample('W').sum()
df_weekly_sum.head()
# Out:
# Date_Time
# 2010-04-04    2149
# 2010-04-11    2814
# 2010-04-18    2938
# 2010-04-25    2925
# 2010-05-02    2846
# Freq: W-SUN, Name: Quantity, dtype: int64

# %%
df_weekly_sum.plot(figsize=(20,8));
plt.grid()

# %%
## Hourly

# %%
df_hourly_sum = data_time_sorted['Quantity'].resample('H').sum()
df_hourly_sum.head(48)
# Out:
# Date_Time
# 2010-04-01 00:00:00    52
# 2010-04-01 01:00:00    16
# 2010-04-01 02:00:00     0
# 2010-04-01 03:00:00     0
# 2010-04-01 04:00:00     0
# 2010-04-01 05:00:00     0
# 2010-04-01 06:00:00     0
# 2010-04-01 07:00:00     0
# 2010-04-01 08:00:00     0
# 2010-04-01 09:00:00     0
# 2010-04-01 10:00:00     0
# 2010-04-01 11:00:00     1
# 2010-04-01 12:00:00    13
# 2010-04-01 13:00:00    29
# 2010-04-01 14:00:00    31
# 2010-04-01 15:00:00    14
# 2010-04-01 16:00:00    44
# 2010-04-01 17:00:00    32
# 2010-04-01 18:00:00    29
# 2010-04-01 19:00:00    40
# 2010-04-01 20:00:00    36
# 2010-04-01 21:00:00    28
# 2010-04-01 22:00:00    28
# 2010-04-01 23:00:00    40
# 2010-04-02 00:00:00    39
# 2010-04-02 01:00:00     8
# 2010-04-02 02:00:00     0
# 2010-04-02 03:00:00     0
# 2010-04-02 04:00:00     0
# 2010-04-02 05:00:00     0
# 2010-04-02 06:00:00     0
# 2010-04-02 07:00:00     0
# 2010-04-02 08:00:00     0
# 2010-04-02 09:00:00     0
# 2010-04-02 10:00:00     0
# ...

# %%
## plotting hourly sales for the first 2 weeks

# %%
df_hourly_sum[:336].plot(figsize=(20,8));
plt.grid()

# %%
df_hourly_sum[:48].plot(figsize=(20,8));
plt.grid()

# %%
## Market Basket  Analysis - workings:
## shortlisted 25 combination of items/products, using Association Rules in KNIME - using pandas to develop combos

# %%
data.columns
# Out:
# Index(['Date', 'Bill Number ', 'Item Desc', 'Time', 'Quantity', 'Rate', 'Tax',
#        'Discount', 'Total', 'Category'],
#       dtype='object')

# %%
## developing a dataset of Items and Rate/Prices

# %%
data_item = data[['Item Desc', 'Rate']]

# %%
# strip the text, for ease of comparison
data_item['Item Desc'] = data_item['Item Desc'].str.strip()
# Out:
# /Users/shubhadeepbhattacharya/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_item_price = data_item.groupby('Item Desc')['Rate'].median()

# %%
data_item_price.describe()
# Out:
# count     580.000000
# mean      226.390078
# std       255.115497
# min         0.010000
# 25%        98.000000
# 50%       150.000000
# 75%       249.000000
# max      2100.000000
# Name: Rate, dtype: float64

# %%
data_item_price.index
# Out:
# Index(['1 AXE TWIST', '1+1 BTL4 SEASON WHITE', '1+1 GLS 4SEASON RED',
#        '1+1 GLS 4SEASONS WHITE', '1+1 KF 1 LITER', '1+1 KF 1/2 LITER',
#        '1+1 KF 2 LITER', '1+1 VLN CAB SAUV (BTL)', '1+1 VLN CAB SAUV (GLS)',
#        '1+1 VLN CAB SAUV CLASIQ (BTL)',
#        ...
#        'WHITE WINE SHEESHA', 'WILD MUSHROOM LINGUINI',
#        'YEMENI GREAT LAKES (AULAIT)', 'YEMENI GREAT LAKES (REG)',
#        'YIN N YANG FONDUE', 'ZEN ROCK SQUARE VASE', 'ZERO SIZE SHOT GLS',
#        'ZINZI RED (GLS)', 'ZINZI WHITE  (GLS)', 'ZINZI WHITE (BTL)'],
#       dtype='object', name='Item Desc', length=580)

# %%
data_item_price[data_item_price.index=='1 AXE TWIST']
# Out:
# Item Desc
# 1 AXE TWIST    70.0
# Name: Rate, dtype: float64

# %%
## pasting the items/combination for getting their respective Rates

# %% [raw]
# ADD HERB ROAST CHICKEN	<---	[LEMON INFUSED CHAR GRILLED VEG]
# CAFFE LATTE	<---	[ADD HAZELNUT FLAVOUR ]
# SATAY CHICKEN PANINI	<---	[ADD FRIES ]
# B.M.T. PANINI	<---	[FRENCH FRIES ]
# ADD FRIES	<---	[COUNTRY ROAST CHICKEN PANINI ]
# CAPPUCCINO	<---	[ADD HAZELNUT FLAVOUR ]
# GREAT LAKES SHAKE	<---	[VANILLA ICECREAM ]
# MASALA CHAI CUTTING	<---	[BUN MASKA & CHAI ]
# LEMON ICED TEA	<---	[BLACK CURRANT ICED TEA ]
# KF DRAUGHT (1LTR)	<---	[KF DRAUGHT (1/2LTR) ]
# B.M.T. PANINI	<---	[ADD FRIES ]
# COOL CALIFORNICA	<---	[MIAMI MELONS ]
# RED BULL 2+1	<---	[ARABIAN MIST ]
# BERRY BLAST	<---	[COOL CALIFORNICA ]
# COUNTRY ROAST CHICKEN PANINI	<---	[SATAY CHICKEN PANINI ]
# THE FERROR ROCHER SHAKE	<---	[KIT KAT SHAKE ]
# COTTAGE CHEESE PANINI	<---	[ADD FRIES ]
# PHILLYCREAM CHEESE &CHILLY PAN	<---	[ADD FRIES ]
# B.M.T. PANINI	<---	[MAGGI NDL ARRABIATA ]
# COOL CALIFORNICA	<---	[PINK LEMONADE ]
#
#
# RED BULL 2+1	<---	[SAMBUCA ]
#
# SAMBUCA	<---	[MAGGI NDL ARRABIATA ]
# RED BULL 2+1	<---	[CALCUTTA MINT ]
#
# SAMBUCA	<---	[RED BULL ENERGY DRINK ]
#
# QUA MINERAL WATER(1000ML)	<---	[B.M.T. PANINI ]
#
# B.M.T. PANINI	<---	[SAMBUCA ]

# %%
list_items1 = ['ADD HERB ROAST CHICKEN','LEMON INFUSED CHAR GRILLED VEG', 'CAFFE LATTE', 'ADD HAZELNUT FLAVOUR',
 'SATAY CHICKEN PANINI', 'ADD FRIES', 'B.M.T. PANINI', 'FRENCH FRIES', 'ADD FRIES',
 'COUNTRY ROAST CHICKEN PANINI']

# %%
for item in list_items1:
    print(item, data_item_price.loc[item] )
# Out:
# ADD HERB ROAST CHICKEN 30.0
# LEMON INFUSED CHAR GRILLED VEG 150.0
# CAFFE LATTE 70.0
# ADD HAZELNUT FLAVOUR 25.0
# SATAY CHICKEN PANINI 115.0
# ADD FRIES 35.0
# B.M.T. PANINI 105.0
# FRENCH FRIES 35.0
# ADD FRIES 35.0
# COUNTRY ROAST CHICKEN PANINI 115.0

# %%
list_items2 = ['CAPPUCCINO', 'ADD HAZELNUT FLAVOUR', 'GREAT LAKES SHAKE', 'VANILLA ICECREAM',
               'MASALA CHAI CUTTING', 'BUN MASKA & CHAI', 'LEMON ICED TEA', 'BLACK CURRANT ICED TEA',
               'KF DRAUGHT (1LTR)','KF DRAUGHT (1/2LTR)', 'B.M.T. PANINI', 'ADD FRIES', 'COOL CALIFORNICA',
               'MIAMI MELONS']

# %%
for item in list_items2:
    print(item, data_item_price.loc[item] )
# Out:
# CAPPUCCINO 60.0
# ADD HAZELNUT FLAVOUR 25.0
# GREAT LAKES SHAKE 110.0
# VANILLA ICECREAM 30.0
# MASALA CHAI CUTTING 40.0
# BUN MASKA & CHAI 60.0
# LEMON ICED TEA 85.0
# BLACK CURRANT ICED TEA 85.0
# KF DRAUGHT (1LTR) 240.0
# KF DRAUGHT (1/2LTR) 125.0
# B.M.T. PANINI 105.0
# ADD FRIES 35.0
# COOL CALIFORNICA 85.0
# MIAMI MELONS 85.0

# %%
list_items3 = ['RED BULL 2+1','ARABIAN MIST', 'BERRY BLAST', 'COOL CALIFORNICA', 'COUNTRY ROAST CHICKEN PANINI',
               'SATAY CHICKEN PANINI', 'THE FERROR ROCHER SHAKE', 'KIT KAT SHAKE', 'COTTAGE CHEESE PANINI',
               'ADD FRIES', 'PHILLYCREAM CHEESE &CHILLY PAN', 'ADD FRIES', 'B.M.T. PANINI', 'MAGGI NDL ARRABIATA',
               'COOL CALIFORNICA','PINK LEMONADE']

# %%
for item in list_items3:
    print(item, data_item_price.loc[item] )
# Out:
# RED BULL 2+1 250.0
# ARABIAN MIST 350.0
# BERRY BLAST 95.0
# COOL CALIFORNICA 85.0
# COUNTRY ROAST CHICKEN PANINI 115.0
# SATAY CHICKEN PANINI 115.0
# THE FERROR ROCHER SHAKE 175.0
# KIT KAT SHAKE 135.0
# COTTAGE CHEESE PANINI 105.0
# ADD FRIES 35.0
# PHILLYCREAM CHEESE &CHILLY PAN 105.0
# ADD FRIES 35.0
# B.M.T. PANINI 105.0
# MAGGI NDL ARRABIATA 125.0
# COOL CALIFORNICA 85.0
# PINK LEMONADE 85.0

# %%
list_items4 = ['RED BULL 2+1', 'SAMBUCA', 'CALCUTTA MINT', 'RED BULL ENERGY DRINK','B.M.T. PANINI', 'POUTINE WITH FRIES']

# %%
for item in list_items4:
    print(item, data_item_price.loc[item] )
# Out:
# RED BULL 2+1 250.0
# SAMBUCA 350.0
# CALCUTTA MINT 350.0
# RED BULL ENERGY DRINK 125.0
# B.M.T. PANINI 105.0
# POUTINE WITH FRIES 125.0

# %%
## reviewing Item popularity

# %%
data_c['Item Desc'] = data_c['Item Desc'].str.strip()

# %%
data_c.groupby('Item Desc').sum()[['Quantity','Total']].sort_values(by='Quantity', ascending=False).head(50)
# Out:
#                                 Quantity       Total
# Item Desc
# NIRVANA HOOKAH SINGLE               8686  2953134.60
# CAPPUCCINO                          7144   550251.99
# MINT FLAVOUR SINGLE                 6019  1840501.00
# GREAT LAKES SHAKE                   5914   843122.11
# SAMBUCA                             4765  2291058.00
# POUTINE WITH FRIES                  3741   580284.11
# QUA  MINERAL WATER(1000ML)          3633   224695.81
# JR.CHL AVALANCHE                    3446   713565.60
# CARLSBERG                           3380   538802.08
# CALCUTTA MINT                       3339  1640860.40
# B.M.T. PANINI                       3010   391066.69
# MASALA CHAI CUTTING                 2993   157279.35
# TUBORG                              2855   381051.73
# MOROCCAN MINT TEA                   2812   159743.50
# LEMON ICED TEA                      2687   282713.79
# GREEN APPLE FLAVOUR SINGLE          2590   793683.00
# ...

# %%
data_c.groupby('Item Desc').sum()[['Quantity','Total']].sort_values(by='Total', ascending=False).head(50)
# Out:
#                                 Quantity       Total
# Item Desc
# NIRVANA HOOKAH SINGLE               8686  2953134.60
# SAMBUCA                             4765  2291058.00
# MINT FLAVOUR SINGLE                 6019  1840501.00
# CALCUTTA MINT                       3339  1640860.40
# N R G  HOOKAH                       2314  1193015.40
# GREAT LAKES SHAKE                   5914   843122.11
# GREEN APPLE FLAVOUR SINGLE          2590   793683.00
# JR.CHL AVALANCHE                    3446   713565.60
# SILVER APPLE SINGLE                 1985   673525.20
# POUTINE WITH FRIES                  3741   580284.11
# ARABIAN MIST                        1213   560406.00
# CAPPUCCINO                          7144   550251.99
# CARLSBERG                           3380   538802.08
# OREO COOKIE SHAKE                   2259   405644.95
# RED WINE SHEESHA                     778   402278.40
# B.M.T. PANINI                       3010   391066.69
# ...

# %%
c = data_c.groupby('Item Desc').sum()[['Quantity','Total']].sort_values(by='Total', ascending=False).head(50)

# %%
c.index
# Out:
# Index(['NIRVANA HOOKAH SINGLE', 'SAMBUCA', 'MINT FLAVOUR SINGLE',
#        'CALCUTTA MINT', 'N R G  HOOKAH', 'GREAT LAKES SHAKE',
#        'GREEN APPLE FLAVOUR SINGLE', 'JR.CHL AVALANCHE', 'SILVER APPLE SINGLE',
#        'POUTINE WITH FRIES', 'ARABIAN MIST', 'CAPPUCCINO', 'CARLSBERG',
#        'OREO COOKIE SHAKE', 'RED WINE SHEESHA', 'B.M.T. PANINI', 'TUBORG',
#        'RED BULL 2+1', 'RED BULL ENERGY DRINK', 'KF DRAUGHT PITCHER (2LTR)',
#        'KF DRAUGHT (1LTR)', 'THE  CHAMPAGNE SHEESHA', 'KIT KAT SHAKE',
#        'RABAT HOOKAH SINGLE', 'MISCHIEF HOOKAH SINGLE', 'LEMON ICED TEA',
#        'PHILLYCREAM CHEESE &CHILLY PAN', 'BERRY BLAST', 'KF DRAUGHT (1/2LTR)',
#        'THE FERROR ROCHER SHAKE', 'AL SIKANDARI HOOKAH SINGLE',
#        'COTTAGE CHEESE PANINI', 'SR.CHL AVALANCHE', 'CAFFE LATTE',
#        'QUA  MINERAL WATER(1000ML)', 'BLUE BERRY SINGLE',
#        'MAGGI NDLCREAM/ CHEE/GARLIC', 'COUNTRY LEMONADE',
# ...

# %%
## List of Items in the Associations - that are in the top 50 products by revenue
n = 0
for item in list_items_tot:
    if item in c.index:
        print(item)
        n = n + 1
print(n)
# Out:
# CAFFE LATTE
# SATAY CHICKEN PANINI
# B.M.T. PANINI
# COUNTRY ROAST CHICKEN PANINI
# CAPPUCCINO
# GREAT LAKES SHAKE
# MASALA CHAI CUTTING
# LEMON ICED TEA
# KF DRAUGHT (1LTR)
# KF DRAUGHT (1/2LTR)
# B.M.T. PANINI
# MIAMI MELONS
# RED BULL 2+1
# ARABIAN MIST
# BERRY BLAST
# COUNTRY ROAST CHICKEN PANINI
# SATAY CHICKEN PANINI
# THE FERROR ROCHER SHAKE
# KIT KAT SHAKE
# COTTAGE CHEESE PANINI
# PHILLYCREAM CHEESE &CHILLY PAN
# B.M.T. PANINI
# MAGGI NDL ARRABIATA
# PINK LEMONADE
# RED BULL 2+1
# SAMBUCA
# SAMBUCA
# CALCUTTA MINT
# RED BULL ENERGY DRINK
# B.M.T. PANINI
# 30

# %%
list_items_tot = list_items1 + list_items2 + list_items3 + list_items4

# %%
list_items_tot
# Out:
# ['ADD HERB ROAST CHICKEN',
#  'LEMON INFUSED CHAR GRILLED VEG',
#  'CAFFE LATTE',
#  'ADD HAZELNUT FLAVOUR',
#  'SATAY CHICKEN PANINI',
#  'ADD FRIES',
#  'B.M.T. PANINI',
#  'FRENCH FRIES',
#  'ADD FRIES',
#  'COUNTRY ROAST CHICKEN PANINI',
#  'CAPPUCCINO',
#  'ADD HAZELNUT FLAVOUR',
#  'GREAT LAKES SHAKE',
#  'VANILLA ICECREAM',
#  'MASALA CHAI CUTTING',
#  'BUN MASKA & CHAI',
#  'LEMON ICED TEA',
#  'BLACK CURRANT ICED TEA',
#  'KF DRAUGHT (1LTR)',
#  'KF DRAUGHT (1/2LTR)',
#  'B.M.T. PANINI',
#  'ADD FRIES',
#  'COOL CALIFORNICA',
#  'MIAMI MELONS',
#  'RED BULL 2+1',
#  'ARABIAN MIST',
#  'BERRY BLAST',
#  'COOL CALIFORNICA',
#  'COUNTRY ROAST CHICKEN PANINI',
#  'SATAY CHICKEN PANINI',
#  'THE FERROR ROCHER SHAKE',
#  'KIT KAT SHAKE',
#  'COTTAGE CHEESE PANINI',
#  'ADD FRIES',
#  'PHILLYCREAM CHEESE &CHILLY PAN',
#  'ADD FRIES',
#  'B.M.T. PANINI',
#  'MAGGI NDL ARRABIATA',
#  'COOL CALIFORNICA',
#  'PINK LEMONADE',
#  'RED BULL 2+1',
#  'SAMBUCA',
#  'CALCUTTA MINT',
# ...

# %%
len(list_items_tot)
# Out:
# 46

# %%
## List of Items in the Associations - that are not in the top 50 products by revenue
m = 0
for item in list_items_tot:
    if item not in c.index:
        print(item)
        m = m + 1
print(m)
# Out:
# ADD HERB ROAST CHICKEN
# LEMON INFUSED CHAR GRILLED VEG
# ADD HAZELNUT FLAVOUR
# ADD FRIES
# FRENCH FRIES
# ADD FRIES
# ADD HAZELNUT FLAVOUR
# VANILLA ICECREAM
# BUN MASKA & CHAI
# BLACK CURRANT ICED TEA
# ADD FRIES
# COOL CALIFORNICA
# COOL CALIFORNICA
# ADD FRIES
# ADD FRIES
# COOL CALIFORNICA
# 16
